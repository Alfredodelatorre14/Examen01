# %% [markdown]
# 1. Formula General

# %%
a = float(input("Digite el valor de a: "))
b = float(input("Digite el valor de b: "))
c = float(input("Digite el valor de c: "))

x1 = ((-(b)+(((b*2)-(4*a*c))*0.5))/(2*a))
x2 = ((-(b)-(((b*2)-(4*a*c))*0.5))/(2*a))

while (((b**2)-(4*a*c))<0):
  print("ERROR, el discriminante tiene que ser positivo")
  a = float(input("Ingrese otro valor para a: "))
  b = float(input("Ingrese otro valor para b: "))
  c = float(input("Ingrese41 otro valor para c: "))
if (((b**2)-(4*a*c))>0):
  x1 = ((-(b)+(((b*2)-(4*a*c))*0.5))/(2*a))
  x2 = ((-(b)-(((b*2)-(4*a*c))*0.5))/(2*a))

print("El resultado de x1: ", x1)
print("El resultado de x2: ", x2)
# Out:
# Digite el valor de a: 8
# Digite el valor de b: 6
# Digite el valor de c: 4
# ERROR, el discriminante tiene que ser positivo
# Ingrese otro valor para a: 8
# Ingrese otro valor para b: 1
# Ingrese4 otro valor para c: 1
# ERROR, el discriminante tiene que ser positivo
# Ingrese otro valor para a: 9
# Ingrese otro valor para b: 43
# Ingrese4 otro valor para c: 3
# El resultado de x1:  -3.0
# El resultado de x2:  -1.7777777777777777

# %% [markdown]
# Funcion e^-x

# %%
import math
e=2.7182818284

miLista=[]
x=-4-1
while x < 10:
  x+=1
  miLista.append(x)
  y= pow(e,-x)
  if y < 0.0025:
    print("El resultado de la funcion es:", y, "En el valor", -x)
# Out:
# El resultado de la funcion es: 0.002478752176989413 En el valor -6
# El resultado de la funcion es: 0.0009118819656931688 En el valor -7
# El resultado de la funcion es: 0.00033546262796080604 En el valor -8
# El resultado de la funcion es: 0.00012340980411080544 En el valor -9
# El resultado de la funcion es: 4.539992977234643e-05 En el valor -10
